# %%
import pandas as pd
import sys
sys.path.append("/home/azureuser/Documents/EulerTurbine/model/")
from  create_figures import *
from radial_turbine import *
import imageio
import math 
rc('text', usetex=True)

#set path to write figures
figpath = "/home/azureuser/Documents/EulerTurbine/results/variableh3new/figures/"
moviepath = "/home/azureuser/Documents/EulerTurbine/results/variableh3new/movies/"


#read info
dfturbine = pd.read_csv("/home/azureuser/Documents/EulerTurbine/data/EulerTurbineData3.txt", sep='\t')


#create extra parameters
dfturbine['tsefficiency']= (dfturbine['state1_thermodynamic_total_H'] - dfturbine['state3_thermodynamic_total_H']) / \
                                     (dfturbine['state1_thermodynamic_total_H']-dfturbine['state3_thermodynamic_static_H'])
dfturbine = scale_variables(dfturbine)
dfturbine['omegaHz']=dfturbine['omega'].apply(lambda x: x/(2*math.pi))
dfturbine['centrifugalterm']=0.5*(dfturbine['state2_kinematic_u_mag']*dfturbine['state2_kinematic_u_mag'] - 
                                  dfturbine['state3_kinematic_u_mag']*dfturbine['state3_kinematic_u_mag'])/1000.
dfturbine['state3_kinematic_ske']=0.5*dfturbine['state3_thermodynamic_static_D']*dfturbine['state3_kinematic_c_mag']*dfturbine['state3_kinematic_c_mag']/1000.0
dfturbine['state2_kinematic_ske']=0.5*dfturbine['state3_thermodynamic_static_D']*dfturbine['state2_kinematic_c_mag']*dfturbine['state2_kinematic_c_mag']/1000.0



#vectors used for filtering
alpha1_vec = dfturbine['state1_kinematic_alpha'].unique()
h2_vec = dfturbine['state2_height'].unique()
alpha2_vec = dfturbine['state2_kinematic_alpha'].unique()
omega_vec = dfturbine['omegaHz'].sort_values().unique()
R_vec = dfturbine['R'].sort_values().unique()
h2_vec = dfturbine['state2_height'].sort_values().unique()
P2_vec = dfturbine['state2_thermodynamic_static_P'].sort_values().unique()
a3_vec = dfturbine['state3_area'].sort_values().unique()
P3_vec = dfturbine['state3_thermodynamic_static_P'].sort_values().unique()

# %%
#optimized versus non-optimal
dfnotopti = dfturbine[dfturbine['optimized']==False]
dfopti = dfturbine[dfturbine['optimized']]

h3_vec = dfopti['state3_height'].unique()
h3_vec2 = dfnotopti['state3_height'].sort_values().unique()
zeta3_vec = dfopti['state3_kinematic_zeta'].unique()
zeta3_vec2 = dfnotopti['state3_kinematic_zeta'].unique()

# %%
h3=h3_vec2[3]
alpha2=alpha2_vec[0]
zeta3= zeta3_vec2[0]
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "tsefficiency",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_eta", 30
             )
plot_contour(dfnotopti,
             "state3_thermodynamic_static_P", 
             "state2_kinematic_alpha", 
             "R",
             "omegaHz", omega_vec[3],
             "state3_height", h3_vec2[1],
             "state1_kinematic_alpha", alpha1_vec[0],
             figpath, "notoptimized_P3alpha2_R", 30
             )
plot_contour(dfnotopti,
             "state3_thermodynamic_static_P", 
             "state2_kinematic_alpha", 
             "state3_kinematic_beta",
             "omegaHz", omega_vec[3],
             "state3_height", h3_vec2[1],
             "state1_kinematic_alpha", alpha1_vec[0],
             figpath, "notoptimized_P3alpha2_beta", 30
             )
plot_contour(dfnotopti,
             "omegaHz", 
             "state3_thermodynamic_static_P", 
             "R",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_R", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_alpha",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_alpha3", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state2_thermodynamic_static_P", "state2_kinematic_w_mag",
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP2_w2mag", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state2_thermodynamic_static_P", "state2_kinematic_w_mach",
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP2_w2mach", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "work",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_work", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_beta",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_beta3", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_w_mag",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_w3mag", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_w_mach",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_w3mach", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state2_thermodynamic_static_P", "state2_kinematic_c_mag",
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP2_c2mag", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state2_thermodynamic_static_P", "state2_kinematic_c_mach",
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP2_c2mach", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "R",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_R", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_c_mag",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_c3mag", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_c_mach",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_c3mach", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_ske",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_ske3", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_thermodynamic_static_H",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_H3", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_thermodynamic_total_H",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_H03", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_thermodynamic_total_H",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_H03", 30
             )
plot_contour(dfnotopti,
             "omegaHz", "state3_thermodynamic_static_P", "work",
             "state2_kinematic_alpha", alpha2,
             "state3_height", h3,
             "state3_kinematic_zeta", zeta3,
             figpath, "notoptimized_omegaP3_work", 30
             )

# %%
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "work",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_work", 30
             )

plot_contour(dfopti,
             "omegaHz", "state2_kinematic_alpha", "work",
             "state3_thermodynamic_static_P", P3_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaalpha2_work", 30
            )
plot_contour(dfopti,
             "omegaHz", "state2_thermodynamic_static_P", "work",
             "state3_thermodynamic_static_P", P3_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP2_work", 30
            )
plot_contour(dfopti,
             "omegaHz", "state2_thermodynamic_static_P", "state2_kinematic_c_mag",
             "state3_thermodynamic_static_P", P3_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP2_c2mag", 30
            )
plot_contour(dfopti,
             "omegaHz", "state2_thermodynamic_static_P", "state2_kinematic_c_mach",
             "state3_thermodynamic_static_P", P3_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP2_c2mach", 30
            )
plot_contour(dfopti,
             "omegaHz", "state2_thermodynamic_static_P", "state2_kinematic_c_theta",
             "state3_thermodynamic_static_P", P3_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP2_c2theta", 30
            )
plot_contour(dfopti,
             "omegaHz", "state2_thermodynamic_static_P", "R",
             "state3_thermodynamic_static_P", P3_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP2_R", 30
            )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_height",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_height3", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_w_mag",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_w3mag", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_w_mach",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_w3mach", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_c_mag",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_c3mag", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_c_mach",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_c3mach", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_c_r",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_c3r", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_beta",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_beta3", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "R",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_R", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_alpha",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_alpha3", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_thermodynamic_static_D",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_D3", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_thermodynamic_static_H",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_H3", 30
             )

plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "centrifugalterm",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_cent", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_thermodynamic_total_H",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_H03", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "tsefficiency",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_eta", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_ske",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_ske3", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_c_mag",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_c3mag", 30
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_c_mach",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
             figpath, "optimized_omegaP3_c3mach", 30
             )

# %%
plot_contour(dfopti,
             "omegaHz", "state3_kinematic_zeta", "state3_height",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "state3_thermodynamic_static_P", P3_vec[0],
             figpath, "optimized_omegazeta3_height3", 21
             )

plot_contour(dfopti,
             "state3_thermodynamic_static_P", "state3_kinematic_zeta", "state3_height",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             "omegaHz", omega_vec[4],
             figpath, "optimized_P3zeta3_height3", 21
             )
plot_contour(dfopti,
             "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_alpha",
             "state2_kinematic_alpha", alpha2_vec[0],
             "state2_height", h2_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],
             figpath, "optimized_omegaP3_alpha3", 21
             )

# %%
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "work","state2_kinematic_alpha", 
            "state1_kinematic_alpha", alpha1_vec[0],
            "state2_height", h2_vec[0],
            moviepath, "state2_kinematic_alpha", 21
            )
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "R","state2_kinematic_alpha", 
            "state1_kinematic_alpha", alpha1_vec[0],
            "state2_height", h2_vec[0],
            moviepath, "omegaP3_R_alpha2", 21
            )
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_c_mag","state3_height", 
            "state2_kinematic_alpha", alpha2_vec[0],
            "state2_height", h2_vec[0],
            moviepath, "omegaP3_c3mag-height", 21
            )
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_c_mag","state3_height", 
            "state2_kinematic_alpha", alpha2_vec[0],
            "state2_height", h2_vec[0],
            moviepath, "omegaP3_c3mag-height", 21
            )
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "tsefficiency","state3_height", 
            "state2_kinematic_alpha", alpha2_vec[0],
            "state2_height", h2_vec[0],
            moviepath, "omegaP3_efficiency-height", 21
            )
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "R","state3_height", 
            "state2_kinematic_alpha", alpha2_vec[0],
            "state2_height", h2_vec[0],
            moviepath, "omegaP3_R-height", 21
            )
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "work","state3_height", 
            "state2_kinematic_alpha", alpha2_vec[0],
            "state2_height", h2_vec[0],
            moviepath, "omegaP3_work-height", 21
            )
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "state3_thermodynamic_static_D","state3_height", 
            "state2_kinematic_alpha", alpha2_vec[0],
            "state2_height", h2_vec[0],
            moviepath, "omegaP3_D3-height", 21
            )
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_w_mag","state3_height", 
            "state2_kinematic_alpha", alpha2_vec[0],
            "state2_height", h2_vec[0],
            moviepath, "omegaP3_w3mag-height", 21
            )
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_alpha","state3_height", 
            "state2_kinematic_alpha", alpha2_vec[0],
            "state2_height", h2_vec[0],
            moviepath, "omegaP3_alpha3-height", 21
            )
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "state3_thermodynamic_static_H","state3_height", 
            "state2_kinematic_alpha", alpha2_vec[-1],
            "state2_height", h2_vec[0],
            moviepath, "omegaP3_H3-height", 21
            )
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_ske","state3_height", 
            "state2_kinematic_alpha", alpha2_vec[-1],
            "state2_height", h2_vec[0],
            moviepath, "omegaP3_ske3-height", 21
            )
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "state3_thermodynamic_total_H","state3_height", 
            "state2_kinematic_alpha", alpha2_vec[-1],
            "state2_height", h2_vec[0],
            moviepath, "omegaP3_H03-height", 21
            )
plot_contour_gif(dfnotopti, 
            "omegaHz", "state3_thermodynamic_static_P", "state3_kinematic_w_mag","state3_height", 
            "state2_kinematic_alpha", alpha2_vec[-1],
            "state2_height", h2_vec[0],
            moviepath, "omegaP3_w3mag-height", 21
            )
plot_contour_gif(dfnotopti, 
            "state2_thermodynamic_static_P", "state3_thermodynamic_static_P", "R","omegaHz", 
            "state1_kinematic_alpha", alpha1_vec[0],
            "state2_height", h2_vec[0],
            moviepath, "notoptimizedR", 21
            )
# Out:
# $\displaystyle \alpha_{2}$ =      70.00 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      70.79 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      71.58 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      72.37 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      73.16 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      73.95 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      74.74 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      75.53 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      76.32 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      77.11 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      77.89 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      78.68 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      79.47 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      80.26 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      81.05 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      81.84 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      82.63 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      83.42 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      84.21 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      85.00 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      70.00 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      70.79 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      71.58 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      72.37 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      73.16 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      73.95 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      74.74 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      75.53 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      76.32 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      77.11 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      77.89 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      78.68 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      79.47 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      80.26 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      81.05 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      81.84 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      82.63 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      83.42 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      84.21 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      85.00 [$\displaystyle ^\circ$]
# $\displaystyle h_{3}$ =       2.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.89 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       3.78 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       4.67 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       5.56 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       6.44 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       7.33 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       8.22 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       9.11 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =      10.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.89 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       3.78 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       4.67 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       5.56 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       6.44 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       7.33 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       8.22 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       9.11 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =      10.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.89 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       3.78 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       4.67 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       5.56 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       6.44 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       7.33 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       8.22 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       9.11 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =      10.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.89 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       3.78 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       4.67 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       5.56 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       6.44 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       7.33 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       8.22 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       9.11 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =      10.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.89 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       3.78 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       4.67 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       5.56 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       6.44 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       7.33 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       8.22 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       9.11 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =      10.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.89 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       3.78 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       4.67 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       5.56 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       6.44 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       7.33 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       8.22 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       9.11 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =      10.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.89 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       3.78 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       4.67 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       5.56 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       6.44 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       7.33 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       8.22 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       9.11 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =      10.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.89 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       3.78 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       4.67 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       5.56 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       6.44 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       7.33 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       8.22 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       9.11 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =      10.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.89 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       3.78 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       4.67 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       5.56 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       6.44 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       7.33 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       8.22 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       9.11 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =      10.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.89 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       3.78 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       4.67 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       5.56 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       6.44 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       7.33 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       8.22 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       9.11 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =      10.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.89 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       3.78 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       4.67 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       5.56 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       6.44 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       7.33 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       8.22 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       9.11 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =      10.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.00 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       2.89 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       3.78 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       4.67 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       5.56 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       6.44 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       7.33 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       8.22 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =       9.11 $\displaystyle [mm] $
# $\displaystyle h_{3}$ =      10.00 $\displaystyle [mm] $
# $\displaystyle f$ =     350.00 [1/s]
# $\displaystyle f$ =     360.53 [1/s]
# $\displaystyle f$ =     371.05 [1/s]
# $\displaystyle f$ =     381.58 [1/s]
# $\displaystyle f$ =     392.11 [1/s]
# $\displaystyle f$ =     402.63 [1/s]
# $\displaystyle f$ =     413.16 [1/s]
# $\displaystyle f$ =     423.68 [1/s]
# $\displaystyle f$ =     434.21 [1/s]
# $\displaystyle f$ =     444.74 [1/s]
# $\displaystyle f$ =     455.26 [1/s]
# $\displaystyle f$ =     465.79 [1/s]
# $\displaystyle f$ =     476.32 [1/s]
# $\displaystyle f$ =     486.84 [1/s]
# $\displaystyle f$ =     497.37 [1/s]
# $\displaystyle f$ =     507.89 [1/s]
# $\displaystyle f$ =     518.42 [1/s]
# $\displaystyle f$ =     528.95 [1/s]
# $\displaystyle f$ =     539.47 [1/s]
# $\displaystyle f$ =     550.00 [1/s]

# %%
plot_contour_gif(dfopti, 
            "omegaHz", "state3_thermodynamic_static_P", "work","state2_kinematic_alpha", 
            "state1_kinematic_alpha", alpha1_vec[0],
            "state2_height", h2_vec[0],
            moviepath, "notoptimized_omegaP3_alpha2", 21
            )
# Out:
# $\displaystyle \alpha_{2}$ =      70.00 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      71.67 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      73.33 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      75.00 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      76.67 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      78.33 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      80.00 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      81.67 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      83.33 [$\displaystyle ^\circ$]
# $\displaystyle \alpha_{2}$ =      85.00 [$\displaystyle ^\circ$]

# %%
plot_contour_gif(dfnotopti, 
            "state2_thermodynamic_static_P", "state3_thermodynamic_static_P", "R","omegaHz", 
            "state1_kinematic_alpha", alpha1_vec[0],
            "state2_height", h2_vec[0],
            moviepath, "notoptimizedR", 21
            )
# Out:
# $\displaystyle f$ =     350.00 [1/s]
# $\displaystyle f$ =     372.22 [1/s]
# $\displaystyle f$ =     394.44 [1/s]
# $\displaystyle f$ =     416.67 [1/s]
# $\displaystyle f$ =     438.89 [1/s]
# $\displaystyle f$ =     461.11 [1/s]
# $\displaystyle f$ =     483.33 [1/s]
# $\displaystyle f$ =     505.56 [1/s]
# $\displaystyle f$ =     527.78 [1/s]
# $\displaystyle f$ =     550.00 [1/s]

# %%
plot_xy_group(dfopti,"state3_thermodynamic_static_P","state3_kinematic_w_mag", 
             "omegaHz", 
             "state1_kinematic_alpha", alpha1_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],\
             "state2_kinematic_alpha", alpha2_vec[-1],
             "state3_kinematic_zeta", zeta3_vec[0],
            
             figpath, "xy_P2wmag3", 21
       )
plot_xy_group(dfopti,"state3_thermodynamic_static_P","state3_kinematic_c_r", 
             "omegaHz", 
             "state1_kinematic_alpha", alpha1_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],\
             "state2_kinematic_alpha", alpha2_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
            
             figpath, "xy_P2cr3", 21
       )
plot_xy_group(dfopti,"state3_thermodynamic_static_P","state3_thermodynamic_static_D", 
             "omegaHz", 
             "state1_kinematic_alpha", alpha1_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],\
             "state2_kinematic_alpha", alpha2_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
            
             figpath, "xy_P2D3", 21
       )
plot_xy_group(dfopti,"state3_thermodynamic_static_P","state3_kinematic_beta", 
             "omegaHz", 
             "state1_kinematic_alpha", alpha1_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],\
             "state2_kinematic_alpha", alpha2_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
            
             figpath, "xy_P2beta3", 21
       )
plot_xy_group(dfopti,"state3_thermodynamic_static_P","state3_thermodynamic_static_H", 
             "omegaHz", 
             "state1_kinematic_alpha", alpha1_vec[0],
             "state1_kinematic_alpha", alpha1_vec[0],\
             "state2_kinematic_alpha", alpha2_vec[0],
             "state3_kinematic_zeta", zeta3_vec[0],
            
             figpath, "xy_P2h3", 21
       )
